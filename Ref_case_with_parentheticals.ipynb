# %%
import json
import pandas as pd
import os

# Load the CSV file
csv_file = 'case_references.csv'
case_references = pd.read_csv(csv_file)

# Initialize a list to store dataframe rows
data_rows = []

# Path to the JSON and TXT directories
json_dir = 'test set for Jesse json'
txt_dir = 'test set for Jesse txt'

# Iterate over JSON files
for json_file in os.listdir(json_dir):
    if json_file.endswith('.json'):
        # Extract base case number (e.g., 'case_38' from 'case_38.json')
        base_case_number = os.path.splitext(json_file)[0]

        # Print the base case number
        print(f"Processing {base_case_number}")

        # Construct full path for JSON file
        json_path = os.path.join(json_dir, json_file)

        # Read JSON file
        with open(json_path, 'r') as file:
            data = json.load(file)

        # Extract ID from JSON
        json_id = data['id']

        # Find matching case in CSV
        matching_case = case_references[case_references['case_id'] == json_id]

        if not matching_case.empty:
            # Get the correct_answer_value
            correct_answer_value = matching_case['correct_answer_value'].iloc[0]

            # Construct corresponding TXT file name and path
            txt_file_name = f"{base_case_number}_summary.txt"
            txt_path = os.path.join(txt_dir, txt_file_name)

            # Read TXT file
            try:
                with open(txt_path, 'r') as file:
                    txt_content = file.read()

                # Add to data rows
                data_rows.append({
                    'input': txt_content,
                    'output': correct_answer_value,
                    'case number': base_case_number,
                    'case_id': json_id
                })
            except FileNotFoundError:
                print(f"File not found: {txt_path}")

# Create a new dataframe from the list of rows
new_df = pd.DataFrame(data_rows)

# Save the new dataframe to CSV
new_df.to_csv('test_set_for_jesse.csv', index=False)
# Out:
# Processing case_1
# Processing case_10
# Processing case_1000
# Processing case_1001
# Processing case_1002
# Processing case_1005
# Processing case_1006
# Processing case_1007
# Processing case_1008
# Processing case_1009
# Processing case_101
# Processing case_1011
# Processing case_1012
# Processing case_1013
# Processing case_1016
# Processing case_1017
# Processing case_1018
# Processing case_102
# Processing case_1020
# Processing case_1021
# Processing case_1023
# Processing case_1025
# Processing case_1026
# Processing case_1027
# Processing case_1028
# Processing case_1029
# Processing case_103
# Processing case_1030
# Processing case_1032
# Processing case_1037
# Processing case_1039
# Processing case_104
# Processing case_1041
# Processing case_1043
# Processing case_1044
# Processing case_1045
# Processing case_1046
# Processing case_1047
# Processing case_1048
# Processing case_1049
# Processing case_1050
# Processing case_1052
# Processing case_1053
# Processing case_1054
# Processing case_1055
# Processing case_1057
# Processing case_1059
# Processing case_106
# Processing case_1060
# Processing case_1062
# Processing case_1063
# Processing case_1064
# Processing case_1065
# Processing case_1066
# Processing case_1067
# Processing case_1069
# Processing case_1070
# Processing case_1073
# Processing case_1074
# Processing case_1075
# Processing case_1076
# Processing case_1077
# Processing case_1078
# Processing case_1081
# Processing case_1082
# Processing case_1083
# Processing case_1084
# Processing case_1085
# Processing case_1089
# Processing case_1090
# Processing case_1093
# Processing case_1096
# Processing case_1100
# Processing case_111
# Processing case_112
# Processing case_113
# Processing case_114
# Processing case_115
# Processing case_116
# Processing case_117
# Processing case_118
# Processing case_119
# Processing case_12
# Processing case_121
# Processing case_123
# Processing case_125
# Processing case_126
# Processing case_127
# Processing case_129
# Processing case_130
# Processing case_132
# Processing case_133
# Processing case_134
# Processing case_135
# Processing case_136
# Processing case_139
# Processing case_14
# Processing case_141
# Processing case_144
# Processing case_145
# Processing case_146
# Processing case_15
# Processing case_151
# Processing case_152
# Processing case_153
# Processing case_154
# Processing case_155
# Processing case_156
# Processing case_157
# Processing case_16
# Processing case_160
# Processing case_162
# Processing case_163
# Processing case_164
# Processing case_165
# Processing case_166
# Processing case_167
# Processing case_168
# Processing case_169
# Processing case_170
# Processing case_171
# Processing case_173
# Processing case_174
# Processing case_175
# Processing case_176
# Processing case_177
# Processing case_178
# Processing case_179
# Processing case_18
# Processing case_181
# Processing case_182
# Processing case_183
# Processing case_184
# Processing case_185
# Processing case_187
# Processing case_188
# Processing case_189
# Processing case_19
# Processing case_191
# Processing case_192
# Processing case_193
# Processing case_194
# Processing case_196
# Processing case_197
# Processing case_198
# Processing case_2
# Processing case_20
# Processing case_202
# Processing case_204
# Processing case_207
# Processing case_211
# Processing case_212
# Processing case_213
# Processing case_214
# Processing case_215
# Processing case_216
# Processing case_217
# Processing case_219
# Processing case_22
# Processing case_220
# Processing case_223
# Processing case_224
# Processing case_225
# Processing case_227
# Processing case_228
# Processing case_231
# Processing case_232
# Processing case_233
# Processing case_235
# Processing case_236
# Processing case_238
# Processing case_239
# Processing case_242
# Processing case_243
# Processing case_244
# Processing case_246
# Processing case_247
# Processing case_248
# Processing case_249
# Processing case_250
# Processing case_251
# Processing case_252
# Processing case_253
# Processing case_254
# Processing case_256
# Processing case_257
# Processing case_258
# Processing case_259
# Processing case_26
# Processing case_260
# Processing case_262
# Processing case_263
# Processing case_265
# Processing case_267
# Processing case_268
# Processing case_27
# Processing case_271
# Processing case_272
# Processing case_275
# Processing case_277
# Processing case_278
# Processing case_279
# Processing case_280
# Processing case_281
# Processing case_282
# Processing case_283
# Processing case_284
# Processing case_285
# Processing case_286
# Processing case_287
# Processing case_288
# Processing case_289
# Processing case_29
# Processing case_290
# Processing case_293
# Processing case_295
# Processing case_296
# Processing case_298
# Processing case_299
# Processing case_3
# Processing case_30
# Processing case_300
# Processing case_304
# Processing case_305
# Processing case_306
# Processing case_307
# Processing case_308
# Processing case_309
# Processing case_310
# Processing case_311
# Processing case_313
# Processing case_314
# Processing case_315
# Processing case_316
# Processing case_319
# Processing case_32
# Processing case_320
# Processing case_322
# Processing case_323
# Processing case_326
# Processing case_327
# Processing case_328
# Processing case_330
# Processing case_332
# Processing case_333
# Processing case_334
# Processing case_335
# Processing case_336
# Processing case_338
# Processing case_34
# Processing case_340
# Processing case_341
# Processing case_343
# Processing case_344
# Processing case_345
# Processing case_346
# Processing case_348
# Processing case_350
# Processing case_351
# Processing case_352
# Processing case_354
# Processing case_355
# Processing case_357
# Processing case_358
# Processing case_359
# Processing case_360
# Processing case_361
# Processing case_363
# Processing case_365
# Processing case_366
# Processing case_367
# Processing case_368
# Processing case_369
# Processing case_37
# Processing case_370
# Processing case_371
# Processing case_373
# Processing case_374
# Processing case_376
# Processing case_377
# Processing case_379
# Processing case_38
# Processing case_380
# Processing case_381
# Processing case_382
# Processing case_383
# Processing case_389
# Processing case_39
# Processing case_392
# Processing case_395
# Processing case_396
# Processing case_397
# Processing case_398
# Processing case_4
# Processing case_40
# Processing case_400
# Processing case_401
# Processing case_403
# Processing case_405
# Processing case_407
# Processing case_408
# Processing case_409
# Processing case_410
# Processing case_411
# Processing case_412
# Processing case_413
# Processing case_415
# Processing case_416
# Processing case_417
# Processing case_419
# Processing case_42
# Processing case_420
# Processing case_422
# Processing case_425
# Processing case_426
# Processing case_427
# Processing case_428
# Processing case_430
# Processing case_431
# Processing case_432
# Processing case_433
# Processing case_434
# Processing case_435
# Processing case_436
# Processing case_437
# Processing case_439
# Processing case_44
# Processing case_441
# Processing case_444
# Processing case_445
# Processing case_446
# Processing case_447
# Processing case_449
# Processing case_45
# Processing case_452
# Processing case_453
# Processing case_455
# Processing case_456
# Processing case_457
# Processing case_458
# Processing case_459
# Processing case_46
# Processing case_461
# File not found: test set for Jesse txt/case_461_summary.txt
# Processing case_462
# Processing case_464
# Processing case_465
# Processing case_466
# Processing case_467
# Processing case_468
# Processing case_469
# Processing case_470
# Processing case_471
# Processing case_472
# Processing case_473
# Processing case_474
# Processing case_476
# Processing case_478
# Processing case_479
# Processing case_48
# Processing case_480
# Processing case_482
# Processing case_483
# Processing case_484
# Processing case_485
# Processing case_486
# Processing case_487
# Processing case_488
# Processing case_489
# Processing case_490
# Processing case_491
# Processing case_492
# Processing case_493
# Processing case_497
# Processing case_5
# Processing case_50
# Processing case_500
# Processing case_503
# Processing case_504
# Processing case_505
# Processing case_506
# Processing case_507
# Processing case_508
# Processing case_509
# Processing case_510
# Processing case_511
# Processing case_512
# Processing case_513
# Processing case_514
# Processing case_515
# Processing case_516
# Processing case_517
# Processing case_518
# Processing case_519
# Processing case_52
# Processing case_521
# Processing case_522
# Processing case_525
# Processing case_526
# Processing case_528
# Processing case_529
# Processing case_53
# Processing case_531
# Processing case_532
# Processing case_533
# Processing case_534
# Processing case_535
# Processing case_536
# Processing case_537
# Processing case_538
# Processing case_539
# Processing case_54
# Processing case_540
# Processing case_541
# Processing case_542
# Processing case_544
# Processing case_549
# Processing case_550
# Processing case_552
# Processing case_554
# Processing case_555
# Processing case_559
# Processing case_56
# Processing case_560
# Processing case_565
# Processing case_566
# Processing case_567
# Processing case_569
# Processing case_572
# Processing case_577
# Processing case_578
# Processing case_579
# Processing case_583
# Processing case_584
# Processing case_586
# Processing case_588
# Processing case_589
# Processing case_59
# Processing case_590
# Processing case_591
# Processing case_592
# Processing case_593
# Processing case_595
# Processing case_596
# Processing case_597
# Processing case_598
# Processing case_599
# Processing case_60
# Processing case_600
# Processing case_602
# Processing case_603
# Processing case_604
# Processing case_605
# Processing case_606
# Processing case_607
# Processing case_608
# Processing case_609
# Processing case_61
# Processing case_613
# Processing case_614
# Processing case_616
# Processing case_617
# Processing case_618
# Processing case_620
# Processing case_622
# Processing case_623
# Processing case_624
# Processing case_625
# Processing case_626
# Processing case_627
# Processing case_628
# Processing case_63
# Processing case_630
# Processing case_633
# Processing case_634
# Processing case_638
# Processing case_639
# Processing case_640
# Processing case_641
# Processing case_642
# Processing case_644
# Processing case_648
# Processing case_649
# Processing case_65
# Processing case_650
# Processing case_651
# Processing case_655
# Processing case_656
# Processing case_657
# Processing case_658
# Processing case_659
# Processing case_66
# Processing case_660
# Processing case_661
# Processing case_663
# Processing case_664
# Processing case_665
# Processing case_666
# Processing case_667
# Processing case_670
# Processing case_671
# Processing case_673
# Processing case_674
# Processing case_675
# Processing case_679
# Processing case_681
# Processing case_682
# Processing case_685
# Processing case_686
# Processing case_687
# Processing case_688
# Processing case_690
# Processing case_691
# Processing case_692
# Processing case_693
# Processing case_694
# Processing case_695
# Processing case_696
# Processing case_697
# Processing case_698
# Processing case_699
# Processing case_7
# Processing case_700
# Processing case_701
# Processing case_702
# Processing case_705
# Processing case_707
# Processing case_708
# Processing case_709
# Processing case_710
# Processing case_711
# Processing case_713
# Processing case_714
# Processing case_717
# Processing case_718
# Processing case_719
# Processing case_72
# Processing case_720
# Processing case_721
# Processing case_723
# Processing case_724
# Processing case_727
# Processing case_728
# Processing case_729
# Processing case_731
# Processing case_732
# Processing case_735
# Processing case_738
# Processing case_739
# Processing case_74
# Processing case_740
# Processing case_741
# Processing case_742
# Processing case_743
# Processing case_746
# Processing case_747
# Processing case_748
# Processing case_749
# Processing case_75
# Processing case_751
# Processing case_752
# Processing case_755
# Processing case_757
# Processing case_758
# Processing case_759
# Processing case_76
# Processing case_760
# Processing case_763
# Processing case_764
# Processing case_765
# Processing case_766
# Processing case_767
# Processing case_768
# Processing case_769
# Processing case_77
# Processing case_770
# Processing case_771
# Processing case_772
# Processing case_773
# Processing case_775
# Processing case_778
# Processing case_779
# Processing case_78
# Processing case_780
# Processing case_781
# Processing case_782
# Processing case_785
# Processing case_786
# Processing case_788
# Processing case_789
# Processing case_79
# Processing case_790
# Processing case_792
# Processing case_793
# Processing case_794
# Processing case_796
# Processing case_797
# Processing case_798
# Processing case_799
# Processing case_800
# Processing case_802
# Processing case_804
# Processing case_805
# Processing case_806
# Processing case_807
# Processing case_808
# Processing case_809
# Processing case_81
# Processing case_810
# Processing case_811
# Processing case_813
# File not found: test set for Jesse txt/case_813_summary.txt
# Processing case_814
# Processing case_815
# Processing case_818
# Processing case_819
# Processing case_820
# Processing case_821
# Processing case_823
# Processing case_824
# Processing case_825
# Processing case_827
# Processing case_828
# Processing case_83
# Processing case_830
# Processing case_831
# Processing case_832
# Processing case_833
# Processing case_836
# Processing case_839
# Processing case_84
# Processing case_841
# Processing case_842
# Processing case_844
# Processing case_845
# Processing case_848
# Processing case_849
# Processing case_85
# Processing case_850
# Processing case_851
# Processing case_852
# Processing case_855
# Processing case_859
# Processing case_860
# Processing case_861
# Processing case_862
# Processing case_863
# Processing case_864
# Processing case_865
# Processing case_868
# Processing case_869
# Processing case_87
# Processing case_870
# Processing case_871
# Processing case_873
# Processing case_874
# Processing case_875
# Processing case_876
# Processing case_878
# Processing case_879
# Processing case_880
# Processing case_883
# Processing case_884
# Processing case_885
# Processing case_887
# Processing case_889
# Processing case_89
# Processing case_891
# Processing case_893
# Processing case_894
# Processing case_895
# Processing case_897
# Processing case_898
# Processing case_899
# Processing case_9
# Processing case_90
# Processing case_901
# Processing case_903
# Processing case_905
# Processing case_906
# Processing case_907
# Processing case_908
# Processing case_909
# Processing case_91
# Processing case_910
# Processing case_911
# Processing case_912
# Processing case_914
# Processing case_915
# Processing case_916
# Processing case_918
# Processing case_92
# Processing case_922
# Processing case_923
# Processing case_926
# Processing case_927
# Processing case_928
# Processing case_93
# Processing case_931
# Processing case_934
# Processing case_936
# Processing case_937
# Processing case_938
# Processing case_94
# Processing case_940
# Processing case_941
# Processing case_942
# Processing case_944
# Processing case_947
# Processing case_948
# Processing case_950
# Processing case_951
# Processing case_952
# Processing case_955
# Processing case_956
# Processing case_957
# Processing case_96
# Processing case_960
# Processing case_961
# Processing case_963
# Processing case_964
# Processing case_965
# Processing case_966
# Processing case_967
# Processing case_968
# Processing case_969
# Processing case_971
# Processing case_973
# Processing case_974
# Processing case_975
# Processing case_976
# Processing case_977
# Processing case_978
# Processing case_98
# Processing case_981
# Processing case_982
# Processing case_983
# Processing case_984
# Processing case_985
# Processing case_986
# Processing case_987
# Processing case_988
# Processing case_989
# Processing case_99
# Processing case_995
# Processing case_996
# Processing case_998
# Processing case_999

# %%
import json
import pandas as pd
import os
from tqdm import tqdm

def process_case_files(csv_file, json_dir, txt_dir):
    # Load the CSV file
    case_references = pd.read_csv(csv_file)

    # Initialize a list to store dataframe rows
    data_rows = []

    # Get the list of JSON files and wrap it with tqdm for a progress bar
    json_files = [f for f in os.listdir(json_dir) if f.endswith('.json')]
    for json_file in tqdm(json_files, desc="Processing JSON files"):
        # Extract base case number
        base_case_number = os.path.splitext(json_file)[0]

        # Construct full path for JSON file
        json_path = os.path.join(json_dir, json_file)

        # Read JSON file
        with open(json_path, 'r') as file:
            data = json.load(file)

        # Extract ID from JSON
        json_id = data['id']

        # Find matching case in CSV
        matching_case = case_references[case_references['case_id'] == json_id]

        if not matching_case.empty:
            # Get the correct_answer_value
            correct_answer_value = matching_case['correct_answer_value'].iloc[0]

            # Construct corresponding TXT file name and path
            txt_file_name = f"{base_case_number}_summary.txt"
            txt_path = os.path.join(txt_dir, txt_file_name)

            # Read TXT file
            try:
                with open(txt_path, 'r') as file:
                    txt_content = file.read()

                # Add to data rows
                data_rows.append({
                    'input': txt_content,
                    'output': correct_answer_value,
                    'case number': base_case_number,
                    'case_id': json_id
                })
            except FileNotFoundError:
                # print(f"File not found: {txt_path}")
                continue

    # Create a new dataframe from the list of rows
    new_df = pd.DataFrame(data_rows)

    # Drop rows with NULL values
    new_df.dropna(inplace=True)

    # Generate output CSV file name based on json_dir
    dataset_type = json_dir.split('_')[-1]  # Extracts 'train', 'test', or 'val' from the filename
    output_csv_name = f"{dataset_type}_dataset.csv"
    new_df.to_csv(output_csv_name, index=False)
    print(f"Processed data saved to {output_csv_name}")

# %%
process_case_files('case_references_train.csv', 'ref_case_jsons_train', 'ref_case_txt_train')

# %%
process_case_files('case_references_test.csv', 'ref_case_jsons_test', 'ref_case_txt_test')
# Out:
# Processing JSON files: 100%|████████████████████████████████████████████████████████████████████████| 3609/3609 [00:17<00:00, 200.85it/s]
# Processed data saved to test_dataset.csv

# %%
process_case_files('case_references_val.csv', 'ref_case_jsons_val', 'ref_case_txt_val')
# Out:
# Processing JSON files:  45%|████████████████████████████████▍                                       | 1609/3574 [00:08<00:10, 192.97it/s]
